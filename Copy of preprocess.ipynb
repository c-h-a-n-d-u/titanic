# %% [markdown]
# >Figure out how to import other .ipynb files as modules
# Do not Optimize in 1st attempt.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import numpy as np
import cv2
import os
import time
import copy

# %%
path1 ="/content/drive/MyDrive/kaggle/OCT2017/test"
path2 ="/content/drive/MyDrive/kaggle/OCT2017/train"
path3 ="/content/drive/MyDrive/kaggle/OCT2017/val"
image_size=(224,224)#(width,height)
#what happens if an image of smaller size resized into larger one?

# %%
def retImgArray(path):
  dir=os.listdir(path)
  total_num_img=83484
  class_wise=[37205,11348,8616,26315]
  
  # for x in dir:
  #   image_list=os.listdir(path+"/"+str(x)+"/")
  #   num_img=len(image_list)
  #   print(num_img)
  #   class_wise[dir.index(x)] = num_img
  #   total_num_img = total_num_img +num_img
  
  # print(total_num_img,"*")
  # images=np.zeros((total_num_img,image_size[0],image_size[1]),dtype=np.int8)

  # start=time.perf_counter()
  # images1=[0]*10000
  # images2=[0]*10000
  # images3=[0]*10000
  # images4=[0]*10000
  # images5=[0]*10000
  # images6=[0]*10000
  # images7=[0]*10000
  # images8=[0]*10000
  # images9=[0]*(total_num_img-80000)

  images1=np.zeros( (10000,image_size[0],image_size[1]) ,dtype=np.int8 )
  images2=copy.deepcopy(images1)
  # images3=copy.deepcopy(images1)
  images3=np.zeros((17205,image_size[0],image_size[1]),dtype=np.int8)
  images4=copy.deepcopy(images1)
  # images5=copy.deepcopy(images1)
  images5=np.zeros((8616,image_size[0],image_size[1]),dtype=np.int8)
  images6=copy.deepcopy(images1)
  images7=copy.deepcopy(images1)
  # images8=copy.deepcopy(images1)
  images8=np.zeros((6315,image_size[0],image_size[1]),dtype=np.int8)
  # end=time.perf_counter()
  # print("time:",end-start)
  # print("*1")

  classNo=np.zeros(total_num_img,dtype=np.int8)
  for i in range(4):
    if i==0:
      i1=0
      i2=class_wise[0]-1
    else:
      i1=i2+1
      i2=i2+class_wise[i]
    print(i1,i2)
    classNo[i1:i2+1]=i
  counter=0
  # for i1,x in enumerate(dir):
  images_list=os.listdir(path+"/CNV/")
  images_list.append(os.listdir(path+"/DME/"))
  images_list.append(os.listdir(path+"/DRUSEN/"))
  images_list.append(os.listdir(path+"/NORMAL/"))
  NoImages=len(images_list)
  print("images_list:",NoImages)
  time.sleep(2)
  # i1=dir.index(x)
  # if i1==0:
  #   base=0
  # else:
  #   base=base+class_wise[i1-1]
  # print("*")

  # images1=[]
  images_list1=images_list[0:10000]
  print("len.of.img_list1:",len(images_list1))
  for i2,y in enumerate(images_list1):
    # real_ind=base+i2
    print(y,counter,":  ","[",classNo[counter],"]")
    start=time.perf_counter()
    images1[i2]=cv2.resize(cv2.imread(path+"/"+"CNV"+"/"+y,0) , image_size ) 
    # images1.append(cv2.resize(cv2.imread(path+"/"+str(x)+"/"+y,0) , image_size ) )
    counter=counter+1
    end=time.perf_counter()
    print(end-start)

  time.sleep(2)

  images_list2=images_list[10000:20000]
  print("len.of.img_list2:",len(images_list2))
  for i2,y in enumerate(images_list2):
    # real_ind=base+i2
    print(y,counter,":  ","[",classNo[counter],"]")
    start=time.perf_counter()
    images2[i2]=cv2.resize(cv2.imread(path+"/"+"CNV"+"/"+y,0) , image_size ) 
    counter=counter+1
    end=time.perf_counter()
    print(end-start)

  time.sleep(2)

  images_list3=images_list[20000:37205]
  print("len.of.img_list3:",len(images_list3))
  for i2,y in enumerate(images_list3):
    # real_ind=base+i2
    print(y,counter,":  ","[",classNo[counter],"]")
    start=time.perf_counter()
    images3[i2]=cv2.resize(cv2.imread(path+"/"+"CNV"+"/"+y,0) , image_size ) 
    counter=counter+1
    end=time.perf_counter()
    print(end-start)
  time.sleep(2)

  images_list4=images_list[37205:48553]
  print("len.of.img_list4:",len(images_list4))
  for i2,y in enumerate(images_list4):
    # real_ind=base+i2
    print(y,counter,":  ","[",classNo[counter],"]")
    start=time.perf_counter()
    images4[i2]=cv2.resize(cv2.imread(path+"/"+"DME"+"/"+y,0) , image_size ) 
    counter=counter+1
    end=time.perf_counter()
    print(end-start)
  time.sleep(2)

  images_list5=images_list[48553:57169]
  print("len.of.img_list5:",len(images_list5))
  for i2,y in enumerate(images_list5):
    # real_ind=base+i2
    print(y,counter,":  ","[",classNo[counter],"]")
    start=time.perf_counter()
    images5[i2]=cv2.resize(cv2.imread(path+"/"+"DRUSEN"+"/"+y,0) , image_size ) 
    counter=counter+1
    end=time.perf_counter()
    print(end-start)
  time.sleep(2)

  images_list6=images_list[57169:67169]
  print("len.of.img_list6:",len(images_list6))
  for i2,y in enumerate(images_list6):
    # real_ind=base+i2
    print(y,counter,":  ","[",classNo[counter],"]")
    start=time.perf_counter()
    images6[i2]=cv2.resize(cv2.imread(path+"/"+"NORMAL"+"/"+y,0) , image_size ) 
    counter=counter+1
    end=time.perf_counter()
    print(end-start)
  time.sleep(2)

  images_list7=images_list[67169:77169]
  print("len.of.img_list7:",len(images_list7))
  for i2,y in enumerate(images_list7):
    # real_ind=base+i2
    print(y,counter,":  ","[",classNo[counter],"]")
    start=time.perf_counter()
    images7[i2]=cv2.resize(cv2.imread(path+"/"+"NORMAL"+"/"+y,0) , image_size ) 
    counter=counter+1
    end=time.perf_counter()
    print(end-start)
  time.sleep(2)

  images_list8=images_list[77169:83484]
  print("len.of.img_list8:",len(images_list8))
  for i2,y in enumerate(images_list8):
    # real_ind=base+i2
    print(y,counter,":  ","[",classNo[counter],"]")
    start=time.perf_counter()
    images8[i2]=cv2.resize(cv2.imread(path+"/"+"NORMAL"+"/"+y,0) , image_size ) 
    counter=counter+1
    end=time.perf_counter()
    print(end-start)
  time.sleep(2)

  # images_list9=images_list[80000:83484]
  # print("len.of.img_list9:",len(images_list9))
  # for i2,y in enumerate(images_list9):
  #   # real_ind=base+i2
  #   print(y,counter,":  ","[",classNo[counter],"]")
  #   start=time.perf_counter()
  #   images9[i2]=cv2.resize(cv2.imread(path+"/"+str(x)+"/"+y,0) , image_size ) 
  #   counter=counter+1
  #   end=time.perf_counter()
  #   print(end-start)
  # time.sleep(2)


  
  
  # images=images1+images2+images3+images4+images5+images6+images7+images8+images9
  # images=np.array(images,dtype=np.int8)
  images=np.concatenate((images1,images2,images3,images4,images5,images6,images7,images8,images9))
  print(images.shape)
  print(classNo.shape)
  return (images,classNo)

# %%
x_train,y_train=retImgArray(path2)
print(x_train.shape,y_train.shape)
# np.save('/content/drive/MyDrive/kaggle/saved_arrays/x_train',x_train)
# np.save('/content/drive/MyDrive/kaggle/saved_arrays/y_train',y_train)
# Out:
# Streaming output truncated to the last 5000 lines.
# CNV-1305450-20.jpeg 34706 :   [ 0 ]
# 0.14813772100023925
# CNV-1305450-204.jpeg 34707 :   [ 0 ]
# 0.13148878500214778
# CNV-1305450-221.jpeg 34708 :   [ 0 ]
# 0.19861690899779205
# CNV-1305450-208.jpeg 34709 :   [ 0 ]
# 0.10288970499823336
# CNV-1305450-217.jpeg 34710 :   [ 0 ]
# 0.15798778700263938
# CNV-1305450-213.jpeg 34711 :   [ 0 ]
# 0.13853532599750906
# CNV-1305450-189.jpeg 34712 :   [ 0 ]
# 0.3238292440000805
# CNV-1305450-211.jpeg 34713 :   [ 0 ]
# 0.17552611399878515
# CNV-1305450-190.jpeg 34714 :   [ 0 ]
# 0.09804760599945439
# CNV-1305450-193.jpeg 34715 :   [ 0 ]
# 0.12096582200319972
# CNV-1305450-203.jpeg 34716 :   [ 0 ]
# 0.18079702500108397
# CNV-1305450-22.jpeg 34717 :   [ 0 ]
# 0.1027903790018172
# CNV-1305450-210.jpeg 34718 :   [ 0 ]
# 0.11007271500056959
# CNV-1305450-188.jpeg 34719 :   [ 0 ]
# 0.13343164899924886
# CNV-1305450-235.jpeg 34720 :   [ 0 ]
# 0.2040683609993721
# ...

# %%
import timeit
my_setup="import cv2"
testcode='''
cv2.imread(r'/content/drive/MyDrive/kaggle/OCT2017/train/CNV/CNV-7902439-14.jpeg',0)
'''
print(timeit.timeit(stmt=testcode, setup=my_setup))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-23078bee6c9c> in <module>()
#       4 cv2.imread(r'/content/drive/MyDrive/kaggle/OCT2017/train/CNV/CNV-7902439-14.jpeg',0)
#       5 '''
# ----> 6 print(timeit.timeit(stmt=testcode, setup=my_setup))
#
# /usr/lib/python3.7/timeit.py in timeit(stmt, setup, timer, number, globals)
#     231            number=default_number, globals=None):
#     232     """Convenience function to create Timer object and call timeit method."""
# --> 233     return Timer(stmt, setup, timer, globals).timeit(number)
#     234
#     235 def repeat(stmt="pass", setup="pass", timer=default_timer,
#
# /usr/lib/python3.7/timeit.py in timeit(self, number)
#     175         gc.disable()
#     176         try:
# --> 177             timing = self.inner(it, self.timer)
#     178         finally:
#     179             if gcold:
#
# ...

# %%
  # for i2,y in enumerate(images_list):
    #   # i2=images_list.index(y)
    #   real_ind=base+i2
    #   print(y,i2,real_ind,":  ","[",classNo[real_ind],"]")
    #   start=time.perf_counter()
      

    #   if real_ind<10000:
    #     images1[real_ind]=cv2.resize(cv2.imread(path+"/"+str(x)+"/"+y,0) , image_size ) 

    #   elif real_ind<20000:
    #     images2[real_ind-10000]=cv2.resize(cv2.imread(path+"/"+str(x)+"/"+y,0) , image_size )

    #   elif real_ind<30000:
    #     images3[real_ind-20000]=cv2.resize(cv2.imread(path+"/"+str(x)+"/"+y,0) , image_size )
      
    #   elif real_ind<40000:
    #     images4[real_ind-30000]=cv2.resize(cv2.imread(path+"/"+str(x)+"/"+y,0) , image_size )
      
    #   elif real_ind<50000:
    #     images5[real_ind-40000]=cv2.resize(cv2.imread(path+"/"+str(x)+"/"+y,0) , image_size )
      
    #   elif real_ind<60000:
    #     images6[real_ind-50000]=cv2.resize(cv2.imread(path+"/"+str(x)+"/"+y,0) , image_size )

    #   elif real_ind<70000:
    #     images7[real_ind-60000]=cv2.resize(cv2.imread(path+"/"+str(x)+"/"+y,0) , image_size )

    #   elif real_ind<80000:
    #     images8[real_ind-70000]=cv2.resize(cv2.imread(path+"/"+str(x)+"/"+y,0) , image_size )
    #   else:
    #     images9[real_ind-80000]=cv2.resize(cv2.imread(path+"/"+str(x)+"/"+y,0) , image_size )

    #   end=time.perf_counter()
    #   print(end-start)
    # # print("*")
    # print("Class:",x,"#Images",NoImages,"ClassArrayLen:",len(classNo))
    # print("LastLabel",classNo[-1])
    # time.sleep(2)

# %%
x_test,y_test=retImgArray(path1)
print(type(x_test),x_test.shape)#shape=(rows,cols)
print(type(y_test),y_test.shape)
np.save('/content/drive/MyDrive/kaggle/saved_arrays/x_test',x_test)
np.save('/content/drive/MyDrive/kaggle/saved_arrays/y_test',y_test)
# Out:
# 968 *
# 0 241
# 242 483
# 484 725
# 726 967
# images_list: 242
# CNV-1016042-2.jpeg :   [ 0 ]
# 0.0073310849993504235
# CNV-1016042-1.jpeg :   [ 0 ]
# 0.0063726329999553855
# CNV-103044-8.jpeg :   [ 0 ]
# 0.008554192999326915
# CNV-103044-11.jpeg :   [ 0 ]
# 0.006745995000528637
# CNV-1131664-1.jpeg :   [ 0 ]
# 0.0062453430000459775
# CNV-1016042-3.jpeg :   [ 0 ]
# 0.008767856000304164
# CNV-103044-10.jpeg :   [ 0 ]
# 0.00599998500001675
# CNV-103044-12.jpeg :   [ 0 ]
# 0.0069240760003594914
# CNV-1188386-4.jpeg :   [ 0 ]
# 0.006058640000446758
# CNV-103044-6.jpeg :   [ 0 ]
# 0.006423423000342154
# CNV-103044-9.jpeg :   [ 0 ]
# 0.006576749000487325
# CNV-1260317-1.jpeg :   [ 0 ]
# 0.006575477999831492
# CNV-103044-4.jpeg :   [ 0 ]
# 0.006299657000454317
# CNV-103044-3.jpeg :   [ 0 ]
# 0.00656597499983036
# CNV-1188386-2.jpeg :   [ 0 ]
# 0.006991621999986819
# CNV-1016042-4.jpeg :   [ 0 ]
# 0.006045391999577987
# CNV-1188386-3.jpeg :   [ 0 ]
# 0.006351727000037499
# ...

# %%
try_x=np.load('/content/drive/MyDrive/kaggle/saved_arrays/x_test.npy')
try_y=np.load('/content/drive/MyDrive/kaggle/saved_arrays/y_test.npy')
print(try_x.all()==x_test.all())
print(try_y.all()==try_y.all())
# Out:
# True
# True

# %%
# !python -V
# Out:
# Python 3.7.12

# %%
'''
img1=cv2.imread("/content/drive/MyDrive/kaggle/OCT2017 /test/CNV/CNV-1016042-1.jpeg",0)
print(img1.shape)
cv2_imshow(img1)
img1=cv2.resize(img1,(image_size[0],image_size[1]))
print(img1.shape)
cv2_imshow(img1)
'''
# Out:
# '\nimg1=cv2.imread("/content/drive/MyDrive/kaggle/OCT2017 /test/CNV/CNV-1016042-1.jpeg",0)\nprint(img1.shape)\ncv2_imshow(img1)\nimg1=cv2.resize(img1,(image_size[0],image_size[1]))\nprint(img1.shape)\ncv2_imshow(img1)\n'

# %%
# %cd '/content/drive/MyDrive/kaggle/saved_arrays'
np.save('/content/drive/MyDrive/kaggle/saved_arrays/x_test',x_test)
np.save('/content/drive/MyDrive/kaggle/saved_arrays/y_test',y_test)

# %%
# %cd '/content/drive/MyDrive/kaggle/saved_arrays'
np.save('x_train_CNVDME',x_train_CNVDME)
np.save('y_train_CNVDME',y_train_CNVDME)
# Out:
# /content/drive/MyDrive/kaggle/saved_arrays
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-62ff6ea1a666> in <module>()
#       1 get_ipython().magic("cd '/content/drive/MyDrive/kaggle/saved_arrays'")
# ----> 2 np.save('x_train_CNVDME',x_train_CNVDME)
#       3 np.save('y_train_CNVDME',y_train_CNVDME)
#
# NameError: name 'np' is not defined

# %%
#Save the arrays for future use
# %cd '/content/drive/MyDrive/kaggle/saved_arrays'
np.save('x_test',x_test)
np.save('y_test',y_test)
# Out:
# /content/drive/MyDrive

# %%
np.save('x_train',x_train)
np.save('y_train',y_train)

# %%
print(len(os.listdir('/content/drive/MyDrive/kaggle/OCT2017 /train/NORMAL')))
# Out:
# 26315

# %%
print()

# %%
# !cat /var/log/colab-jupyter.lo
# Out:
# cat: /var/log/colab-jupyter.lo: No such file or directory
